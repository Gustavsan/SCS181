# %%
def step1(n):
    b = 2
    while True:
        a = n ** (1 / b)
        b += 1
        if a.is_integer():
            print(f"{n} is composite | Step 1")
            return False
        if a < 2:
            return True

# %%
def step2(n):
    L = math.floor(4 * math.log2(n) ** 2)
    condition = True
    r = 1
    while condition:
        r += 1
        condition = False
        j = 0
        while j <= L and not condition:
            j += 1
            if pow(n, j, r) == 1:
                condition = True
    return r

# %%
def step3(n, r):
    if n <= r:
        print(f"{n} is prime | Step 3")
        return True
    max_a = floor(2 * math.sqrt(r) * math.log2(n))
    R.<x> = PolynomialRing(Integers(n))
    Z = R.quotient((x^r)-1)
    for a in range(1, max_a + 1):
        q = Z((x + a)^n)
        d = x^(Mod(n, r)) + a
        if (q != d):
            print(f"{n} is composite | Step 3")
            return False
    print(f"{n} is prime | Step 3")
    return True

# %%
import time
import matplotlib.pyplot as plt

def aks(n):
    if n <= 1:
        print("Error: n must be > 1.")
        return -1
    first_step = step1(n)
    if first_step:
        r = step2(n)
        third_step = step3(n, r)
        if not third_step:
            return 0
    else:
        return 0
    return 1

times = []
numbers = []
def main(n_):
    start = time.time()
    aks_res = aks(n_)
    test = is_prime(n_)
    if not ((aks_res == 0 and not test) or (aks_res == 1 and test)):
        print('ERROR')
        return n_, -1
    end = time.time() - start
    print(end)
    print('===' * 20)
    return n_, end

for i in range(2, 2^14):
    number, time_ = main(i)
    numbers.append(number)
    times.append(time_)
# Out:
# 2 is prime | Step 3
# 0.00244903564453125
# ============================================================
# 3 is prime | Step 3
# 0.0023241043090820312
# ============================================================
# 4 is composite | Step 1
# 4.220008850097656e-05
# ============================================================
# 5 is prime | Step 3
# 0.005902528762817383
# ============================================================
# 6 is composite | Step 3
# 0.0067291259765625
# ============================================================
# 7 is prime | Step 3
# 0.007361650466918945
# ============================================================
# 8 is composite | Step 1
# 0.03429913520812988
# ============================================================
# 9 is composite | Step 1
# 4.839897155761719e-05
# ============================================================
# 10 is composite | Step 3
# 0.01796126365661621
# ============================================================
# 11 is prime | Step 3
# 0.011053085327148438
# ============================================================
# 12 is composite | Step 3
# 0.010138511657714844
# ============================================================
# 13 is prime | Step 3
# 0.009150981903076172
# ============================================================
# 14 is composite | Step 3
# 0.06529402732849121
# ============================================================
# 15 is composite | Step 3
# 0.01521754264831543
# ============================================================
# 16 is composite | Step 1
# 4.744529724121094e-05
# ============================================================
# 17 is prime | Step 3
# 0.013365983963012695
# ============================================================
# 18 is composite | Step 3
# 0.01656651496887207
# ============================================================
# 19 is prime | Step 3
# 0.05361771583557129
# ============================================================
# 20 is composite | Step 3
# 0.011147737503051758
# ============================================================
# 21 is composite | Step 3
# 0.01083064079284668
# ============================================================
# 22 is composite | Step 3
# 0.07961177825927734
# ============================================================
# 23 is prime | Step 3
# 0.024555683135986328
# ============================================================
# 24 is composite | Step 3
# 0.012119054794311523
# ============================================================
# 25 is composite | Step 1
# 0.0004267692565917969
# ============================================================
# 26 is composite | Step 3
# 0.007776021957397461
# ============================================================
# 27 is composite | Step 1
# 0.0013420581817626953
# ============================================================
# 28 is composite | Step 3
# 0.043984174728393555
# ============================================================
# 29 is prime | Step 3
# 0.015504837036132812
# ============================================================
# 30 is composite | Step 3
# 0.011828184127807617
# ============================================================
# 31 is prime | Step 3
# 0.014757156372070312
# ============================================================
# 32 is composite | Step 1
# 0.004452705383300781
# ============================================================
# 33 is composite | Step 3
# 0.057210683822631836
# ============================================================
# 34 is composite | Step 3
# 0.013286828994750977
# ============================================================
# 35 is composite | Step 3
# 0.08227968215942383
# ============================================================
# 36 is composite | Step 1
# 5.4836273193359375e-05
# ============================================================
# 37 is prime | Step 3
# 0.01811504364013672
# ============================================================
# 38 is composite | Step 3
# 0.014274835586547852
# ============================================================
# 39 is composite | Step 3
# 0.06472277641296387
# ============================================================
# 40 is composite | Step 3
# 0.018999338150024414
# ============================================================
# 41 is prime | Step 3
# 0.02002120018005371
# ============================================================
# 42 is composite | Step 3
# 0.06869840621948242
# ============================================================
# 43 is prime | Step 3
# 0.029762983322143555
# ============================================================
# 44 is composite | Step 3
# 0.06571364402770996
# ============================================================
# 45 is composite | Step 3
# 0.018680095672607422
# ============================================================
# 46 is composite | Step 3
# 0.01798272132873535
# ============================================================
# 47 is prime | Step 3
# 0.06597185134887695
# ============================================================
# 48 is composite | Step 3
# 0.014787435531616211
# ============================================================
# 49 is composite | Step 1
# 4.76837158203125e-05
# ============================================================
# 50 is composite | Step 3
# 0.021712779998779297
# ============================================================
# 51 is composite | Step 3
# 0.06653118133544922
# ============================================================
# 52 is composite | Step 3
# 0.01151728630065918
# ============================================================
# 53 is prime | Step 3
# 0.07602095603942871
# ============================================================
# 54 is composite | Step 3
# 0.021253585815429688
# ============================================================
# 55 is composite | Step 3
# 0.016183853149414062
# ============================================================
# 56 is composite | Step 3
# 0.014932870864868164
# ============================================================
# 57 is composite | Step 3
# 0.0765080451965332
# ============================================================
# 58 is composite | Step 3
# 0.015627622604370117
# ============================================================
# 59 is prime | Step 3
# 0.0669863224029541
# ============================================================
# 60 is composite | Step 3
# 0.02166128158569336
# ============================================================
# 61 is prime | Step 3
# 0.06797528266906738
# ============================================================
# 62 is composite | Step 3
# 0.038041114807128906
# ============================================================
# 63 is composite | Step 3
# 0.013724565505981445
# ============================================================
# 64 is composite | Step 1
# 3.4332275390625e-05
# ============================================================
# 65 is composite | Step 3
# 0.061417341232299805
# ============================================================
# 66 is composite | Step 3
# 0.027102947235107422
# ============================================================
# 67 is prime | Step 3
# 0.060994863510131836
# ============================================================
# 68 is composite | Step 3
# 0.017889976501464844
# ============================================================
# 69 is composite | Step 3
# 0.01688361167907715
# ============================================================
# 70 is composite | Step 3
# 0.0654902458190918
# ============================================================
# 71 is prime | Step 3
# 0.09259653091430664
# ============================================================
# 72 is composite | Step 3
# 0.020544767379760742
# ============================================================
# 73 is prime | Step 3
# 0.08369827270507812
# ============================================================
# 74 is composite | Step 3
# 0.018876314163208008
# ============================================================
# 75 is composite | Step 3
# 0.0739600658416748
# ============================================================
# 76 is composite | Step 3
# 0.020107507705688477
# ============================================================
# 77 is composite | Step 3
# 0.028938770294189453
# ============================================================
# 78 is composite | Step 3
# 0.05862832069396973
# ============================================================
# 79 is prime | Step 3
# 0.04104185104370117
# ============================================================
# 80 is composite | Step 3
# 0.09324336051940918
# ============================================================
# 81 is composite | Step 1
# 7.009506225585938e-05
# ============================================================
# 82 is composite | Step 3
# 0.02236485481262207
# ============================================================
# 83 is prime | Step 3
# 0.10543608665466309
# ============================================================
# 84 is composite | Step 3
# 0.01227712631225586
# ============================================================
# 85 is composite | Step 3
# 0.03557109832763672
# ============================================================
# 86 is composite | Step 3
# 0.04264259338378906
# ============================================================
# 87 is composite | Step 3
# 0.05343484878540039
# ============================================================
# 88 is composite | Step 3
# 0.03001880645751953
# ============================================================
# 89 is prime | Step 3
# 0.10506916046142578
# ============================================================
# 90 is composite | Step 3
# 0.022561073303222656
# ============================================================
# 91 is composite | Step 3
# 0.06769013404846191
# ============================================================
# 92 is composite | Step 3
# 0.020107507705688477
# ============================================================
# 93 is composite | Step 3
# 0.05872797966003418
# ============================================================
# 94 is composite | Step 3
# 0.021663904190063477
# ============================================================
# 95 is composite | Step 3
# 0.015016317367553711
# ============================================================
# 96 is composite | Step 3
# 0.06215190887451172
# ============================================================
# 97 is prime | Step 3
# 0.10270023345947266
# ============================================================
# 98 is composite | Step 3
# 0.027076005935668945
# ============================================================
# 99 is composite | Step 3
# 0.05407357215881348
# ============================================================
# 100 is composite | Step 1
# 6.365776062011719e-05
# ============================================================
# 101 is prime | Step 3
# 0.047309160232543945
# ============================================================
# 102 is composite | Step 3
# 0.06712460517883301
# ============================================================
# 103 is prime | Step 3
# 0.10909056663513184
# ============================================================
# 104 is composite | Step 3
# 0.024201631546020508
# ============================================================
# 105 is composite | Step 3
# 0.06296730041503906
# ============================================================
# 106 is composite | Step 3
# 0.019728422164916992
# ============================================================
# 107 is prime | Step 3
# 0.09666204452514648
# ============================================================
# 108 is composite | Step 3
# 0.07546329498291016
# ============================================================
# 109 is prime | Step 3
# 0.10191106796264648
# ============================================================
# 110 is composite | Step 3
# 0.021709442138671875
# ============================================================
# 111 is composite | Step 3
# 0.022752761840820312
# ============================================================
# 112 is composite | Step 3
# 0.06867480278015137
# ============================================================
# 113 is prime | Step 3
# 0.11450338363647461
# ============================================================
# 114 is composite | Step 3
# 0.08840489387512207
# ============================================================
# 115 is composite | Step 3
# 0.02437877655029297
# ============================================================
# 116 is composite | Step 3
# 0.06880521774291992
# ============================================================
# 117 is composite | Step 3
# 0.023441314697265625
# ============================================================
# 118 is composite | Step 3
# 0.07704353332519531
# ============================================================
# 119 is composite | Step 3
# 0.19149327278137207
# ============================================================
# 120 is composite | Step 3
# 0.024010181427001953
# ============================================================
# 121 is composite | Step 1
# 9.894371032714844e-05
# ============================================================
# 122 is composite | Step 3
# 0.020391464233398438
# ============================================================
# 123 is composite | Step 3
# 0.06942296028137207
# ============================================================
# 124 is composite | Step 3
# 0.02277350425720215
# ============================================================
# 125 is composite | Step 1
# 0.002703428268432617
# ============================================================
# 126 is composite | Step 3
# 0.08276581764221191
# ============================================================
# 127 is prime | Step 3
# 0.1182708740234375
# ============================================================
# 128 is composite | Step 1
# 0.008515596389770508
# ============================================================
# 129 is composite | Step 3
# 0.06701779365539551
# ============================================================
# 130 is composite | Step 3
# 0.019750595092773438
# ============================================================
# 131 is prime | Step 3
# 0.09975695610046387
# ============================================================
# 132 is composite | Step 3
# 0.05956101417541504
# ============================================================
# 133 is composite | Step 3
# 0.04106736183166504
# ============================================================
# 134 is composite | Step 3
# 0.06724429130554199
# ============================================================
# 135 is composite | Step 3
# 0.02446913719177246
# ============================================================
# 136 is composite | Step 3
# 0.05978822708129883
# ============================================================
# 137 is prime | Step 3
# 0.12500214576721191
# ============================================================
# 138 is composite | Step 3
# 0.07537007331848145
# ============================================================
# 139 is prime | Step 3
# 0.12172436714172363
# ============================================================
# 140 is composite | Step 3
# 0.025205612182617188
# ============================================================
# 141 is composite | Step 3
# 0.02062845230102539
# ============================================================
# 142 is composite | Step 3
# 0.0814814567565918
# ============================================================
# 143 is composite | Step 3
# 0.025080204010009766
# ============================================================
# 144 is composite | Step 1
# 4.6253204345703125e-05
# ============================================================
# 145 is composite | Step 3
# 0.07289600372314453
# ============================================================
# 146 is composite | Step 3
# 0.03171396255493164
# ============================================================
# 147 is composite | Step 3
# 0.0745246410369873
# ============================================================
# 148 is composite | Step 3
# 0.022426366806030273
# ============================================================
# 149 is prime | Step 3
# 0.11102557182312012
# ============================================================
# 150 is composite | Step 3
# 0.08261322975158691
# ============================================================
# 151 is prime | Step 3
# 0.12113523483276367
# ============================================================
# 152 is composite | Step 3
# 0.07721948623657227
# ============================================================
# 153 is composite | Step 3
# 0.08160185813903809
# ============================================================
# 154 is composite | Step 3
# 0.025236845016479492
# ============================================================
# 155 is composite | Step 3
# 0.07428240776062012
# ============================================================
# 156 is composite | Step 3
# 0.0269773006439209
# ============================================================
# 157 is prime | Step 3
# 0.18526291847229004
# ============================================================
# 158 is composite | Step 3
# 0.02927708625793457
# ============================================================
# 159 is composite | Step 3
# 0.07409000396728516
# ============================================================
# 160 is composite | Step 3
# 0.021376848220825195
# ============================================================
# 161 is composite | Step 3
# 0.07443046569824219
# ============================================================
# 162 is composite | Step 3
# 0.021574020385742188
# ============================================================
# 163 is prime | Step 3
# 0.18552303314208984
# ============================================================
# 164 is composite | Step 3
# 0.02013397216796875
# ============================================================
# 165 is composite | Step 3
# 0.0722358226776123
# ============================================================
# 166 is composite | Step 3
# 0.022419214248657227
# ============================================================
# 167 is prime | Step 3
# 0.1867518424987793
# ============================================================
# 168 is composite | Step 3
# 0.0802774429321289
# ============================================================
# 169 is composite | Step 1
# 6.508827209472656e-05
# ============================================================
# 170 is composite | Step 3
# 0.022511005401611328
# ============================================================
# 171 is composite | Step 3
# 0.020380020141601562
# ============================================================
# 172 is composite | Step 3
# 0.022322893142700195
# ============================================================
# 173 is prime | Step 3
# 0.19201350212097168
# ============================================================
# 174 is composite | Step 3
# 0.03579235076904297
# ============================================================
# 175 is composite | Step 3
# 0.08914637565612793
# ============================================================
# 176 is composite | Step 3
# 0.023998260498046875
# ============================================================
# 177 is composite | Step 3
# 0.0534517765045166
# ============================================================
# 178 is composite | Step 3
# 0.022340059280395508
# ============================================================
# 179 is prime | Step 3
# 0.6606547832489014
# ============================================================
# 180 is composite | Step 3
# 0.02706432342529297
# ============================================================
# 181 is prime | Step 3
# 0.3428034782409668
# ============================================================
# 182 is composite | Step 3
# 0.05298781394958496
# ============================================================
# 183 is composite | Step 3
# 0.026909589767456055
# ============================================================
# 184 is composite | Step 3
# 0.05636191368103027
# ============================================================
# 185 is composite | Step 3
# 0.04895806312561035
# ============================================================
# 186 is composite | Step 3
# 0.05343818664550781
# ============================================================
# 187 is composite | Step 3
# 0.03569626808166504
# ============================================================
# 188 is composite | Step 3
# 0.07166266441345215
# ============================================================
# 189 is composite | Step 3
# 0.03152751922607422
# ============================================================
# 190 is composite | Step 3
# 0.07376694679260254
# ============================================================
# 191 is prime | Step 3
# 0.3009674549102783
# ============================================================
# 192 is composite | Step 3
# 0.07626461982727051
# ============================================================
# 193 is prime | Step 3
# 0.3056957721710205
# ============================================================
# 194 is composite | Step 3
# 0.023290157318115234
# ============================================================
# 195 is composite | Step 3
# 0.07129549980163574
# ============================================================
# 196 is composite | Step 1
# 6.842613220214844e-05
# ============================================================
# 197 is prime | Step 3
# 0.24721503257751465
# ============================================================
# 198 is composite | Step 3
# 0.07637739181518555
# ============================================================
# 199 is prime | Step 3
# 0.6783769130706787
# ============================================================
# 200 is composite | Step 3
# 0.20068788528442383
# ============================================================
# 201 is composite | Step 3
# 0.10071921348571777
# ============================================================
# 202 is composite | Step 3
# 0.11275553703308105
# ============================================================
# 203 is composite | Step 3
# 0.1090700626373291
# ============================================================
# 204 is composite | Step 3
# 0.017825603485107422
# ============================================================
# 205 is composite | Step 3
# 0.06207847595214844
# ============================================================
# 206 is composite | Step 3
# 0.016471385955810547
# ============================================================
# 207 is composite | Step 3
# 0.016978025436401367
# ============================================================
# 208 is composite | Step 3
# 0.07947039604187012
# ============================================================
# 209 is composite | Step 3
# 0.0362393856048584
# ============================================================
# 210 is composite | Step 3
# 0.06938648223876953
# ============================================================
# 211 is prime | Step 3
# 0.31879258155822754
# ============================================================
# 212 is composite | Step 3
# 0.07769107818603516
# ============================================================
# 213 is composite | Step 3
# 0.07735681533813477
# ============================================================
# 214 is composite | Step 3
# 0.02625298500061035
# ============================================================
# 215 is composite | Step 3
# 0.08080935478210449
# ============================================================
# 216 is composite | Step 1
# 0.0041158199310302734
# ============================================================
# 217 is composite | Step 3
# 0.028889894485473633
# ============================================================
# 218 is composite | Step 3
# 0.02334737777709961
# ============================================================
# 219 is composite | Step 3
# 0.0792241096496582
# ============================================================
# 220 is composite | Step 3
# 0.023272037506103516
# ============================================================
# 221 is composite | Step 3
# 0.08489990234375
# ============================================================
# 222 is composite | Step 3
# 0.015477418899536133
# ============================================================
# 223 is prime | Step 3
# 0.3072500228881836
# ============================================================
# 224 is composite | Step 3
# 0.07028889656066895
# ============================================================
# 225 is composite | Step 1
# 6.008148193359375e-05
# ============================================================
# 226 is composite | Step 3
# 0.02057671546936035
# ============================================================
# 227 is prime | Step 3
# 0.30141353607177734
# ============================================================
# 228 is composite | Step 3
# 0.02077937126159668
# ============================================================
# 229 is prime | Step 3
# 0.26923704147338867
# ============================================================
# 230 is composite | Step 3
# 0.017058610916137695
# ============================================================
# 231 is composite | Step 3
# 0.07401704788208008
# ============================================================
# 232 is composite | Step 3
# 0.01649332046508789
# ============================================================
# 233 is prime | Step 3
# 0.32719850540161133
# ============================================================
# 234 is composite | Step 3
# 0.06351542472839355
# ============================================================
# 235 is composite | Step 3
# 0.02717137336730957
# ============================================================
# 236 is composite | Step 3
# 0.07901597023010254
# ============================================================
# 237 is composite | Step 3
# 0.031098365783691406
# ============================================================
# 238 is composite | Step 3
# 0.06792521476745605
# ============================================================
# 239 is prime | Step 3
# 0.3089942932128906
# ============================================================
# 240 is composite | Step 3
# 0.07428359985351562
# ============================================================
# 241 is prime | Step 3
# 0.3363220691680908
# ============================================================
# 242 is composite | Step 3
# 0.07506155967712402
# ============================================================
# 243 is composite | Step 1
# 0.0064542293548583984
# ============================================================
# 244 is composite | Step 3
# 0.034049034118652344
# ============================================================
# 245 is composite | Step 3
# 0.06601738929748535
# ============================================================
# 246 is composite | Step 3
# 0.024158477783203125
# ============================================================
# 247 is composite | Step 3
# 0.0754094123840332
# ============================================================
# 248 is composite | Step 3
# 0.08696484565734863
# ============================================================
# 249 is composite | Step 3
# 0.09518218040466309
# ============================================================
# 250 is composite | Step 3
# 0.10728287696838379
# ============================================================
# 251 is prime | Step 3
# 0.3348557949066162
# ============================================================
# 252 is composite | Step 3
# 0.0866401195526123
# ============================================================
# 253 is composite | Step 3
# 0.0176846981048584
# ============================================================
# 254 is composite | Step 3
# 0.0591120719909668
# ============================================================
# 255 is composite | Step 3
# 0.01593184471130371
# ============================================================
# 256 is composite | Step 1
# 5.817413330078125e-05
# ============================================================
# 257 is prime | Step 3
# 0.29754090309143066
# ============================================================
# 258 is composite | Step 3
# 0.07566380500793457
# ============================================================
# 259 is composite | Step 3
# 0.030780792236328125
# ============================================================
# 260 is composite | Step 3
# 0.020482301712036133
# ============================================================
# 261 is composite | Step 3
# 0.08666467666625977
# ============================================================
# 262 is composite | Step 3
# 0.09554076194763184
# ============================================================
# 263 is prime | Step 3
# 0.47680234909057617
# ============================================================
# 264 is composite | Step 3
# 0.025421142578125
# ============================================================
# 265 is composite | Step 3
# 0.06578493118286133
# ============================================================
# 266 is composite | Step 3
# 0.025178909301757812
# ============================================================
# 267 is composite | Step 3
# 0.017180204391479492
# ============================================================
# 268 is composite | Step 3
# 0.08526277542114258
# ============================================================
# 269 is prime | Step 3
# 0.3988630771636963
# ============================================================
# 270 is composite | Step 3
# 0.07666182518005371
# ============================================================
# 271 is prime | Step 3
# 0.4179375171661377
# ============================================================
# 272 is composite | Step 3
# 0.021578550338745117
# ============================================================
# 273 is composite | Step 3
# 0.06722521781921387
# ============================================================
# 274 is composite | Step 3
# 0.01783466339111328
# ============================================================
# 275 is composite | Step 3
# 0.08368992805480957
# ============================================================
# 276 is composite | Step 3
# 0.022109270095825195
# ============================================================
# 277 is prime | Step 3
# 0.502068281173706
# ============================================================
# 278 is composite | Step 3
# 0.08132052421569824
# ============================================================
# 279 is composite | Step 3
# 0.028282880783081055
# ============================================================
# 280 is composite | Step 3
# 0.06955599784851074
# ============================================================
# 281 is prime | Step 3
# 0.30359935760498047
# ============================================================
# 282 is composite | Step 3
# 0.01750779151916504
# ============================================================
# 283 is prime | Step 3
# 0.3685433864593506
# ============================================================
# 284 is composite | Step 3
# 0.01869487762451172
# ============================================================
# 285 is composite | Step 3
# 0.01750802993774414
# ============================================================
# 286 is composite | Step 3
# 0.07368206977844238
# ============================================================
# 287 is composite | Step 3
# 0.027939796447753906
# ============================================================
# 288 is composite | Step 3
# 0.08799195289611816
# ============================================================
# 289 is composite | Step 1
# 5.173683166503906e-05
# ============================================================
# 290 is composite | Step 3
# 0.08333349227905273
# ============================================================
# 291 is composite | Step 3
# 0.028084993362426758
# ============================================================
# 292 is composite | Step 3
# 0.07389664649963379
# ============================================================
# 293 is prime | Step 3
# 0.5203342437744141
# ============================================================
# 294 is composite | Step 3
# 0.08242201805114746
# ============================================================
# 295 is composite | Step 3
# 0.09926724433898926
# ============================================================
# 296 is composite | Step 3
# 0.030401229858398438
# ============================================================
# 297 is composite | Step 3
# 0.06882977485656738
# ============================================================
# 298 is composite | Step 3
# 0.09342479705810547
# ============================================================
# 299 is composite | Step 3
# 0.031096220016479492
# ============================================================
# 300 is composite | Step 3
# 0.0794222354888916
# ============================================================
# 301 is composite | Step 3
# 0.0889883041381836
# ============================================================
# 302 is composite | Step 3
# 0.02578592300415039
# ============================================================
# 303 is composite | Step 3
# 0.08134293556213379
# ============================================================
# 304 is composite | Step 3
# 0.08730626106262207
# ============================================================
# 305 is composite | Step 3
# 0.09248948097229004
# ============================================================
# 306 is composite | Step 3
# 0.029994487762451172
# ============================================================
# 307 is prime | Step 3
# 0.4845719337463379
# ============================================================
# 308 is composite | Step 3
# 0.08513641357421875
# ============================================================
# 309 is composite | Step 3
# 0.030071258544921875
# ============================================================
# 310 is composite | Step 3
# 0.07072210311889648
# ============================================================
# 311 is prime | Step 3
# 0.4206840991973877
# ============================================================
# 312 is composite | Step 3
# 0.0836026668548584
# ============================================================
# 313 is prime | Step 3
# 1.7238235473632812
# ============================================================
# 314 is composite | Step 3
# 0.07065582275390625
# ============================================================
# 315 is composite | Step 3
# 0.03001880645751953
# ============================================================
# 316 is composite | Step 3
# 0.08440542221069336
# ============================================================
# 317 is prime | Step 3
# 0.7086987495422363
# ============================================================
# 318 is composite | Step 3
# 0.07554030418395996
# ============================================================
# 319 is composite | Step 3
# 0.031385183334350586
# ============================================================
# 320 is composite | Step 3
# 0.07383394241333008
# ============================================================
# 321 is composite | Step 3
# 0.03690910339355469
# ============================================================
# 322 is composite | Step 3
# 0.024076223373413086
# ============================================================
# 323 is composite | Step 3
# 0.024544715881347656
# ============================================================
# 324 is composite | Step 1
# 5.054473876953125e-05
# ============================================================
# 325 is composite | Step 3
# 0.08617949485778809
# ============================================================
# 326 is composite | Step 3
# 0.08538174629211426
# ============================================================
# 327 is composite | Step 3
# 0.09706473350524902
# ============================================================
# 328 is composite | Step 3
# 0.027328014373779297
# ============================================================
# 329 is composite | Step 3
# 0.08080053329467773
# ============================================================
# 330 is composite | Step 3
# 0.0168914794921875
# ============================================================
# 331 is prime | Step 3
# 0.6776742935180664
# ============================================================
# 332 is composite | Step 3
# 0.025898456573486328
# ============================================================
# 333 is composite | Step 3
# 0.07832217216491699
# ============================================================
# 334 is composite | Step 3
# 0.07787299156188965
# ============================================================
# 335 is composite | Step 3
# 0.03071284294128418
# ============================================================
# 336 is composite | Step 3
# 0.08767199516296387
# ============================================================
# 337 is prime | Step 3
# 0.6055028438568115
# ============================================================
# 338 is composite | Step 3
# 0.018839597702026367
# ============================================================
# 339 is composite | Step 3
# 0.0692591667175293
# ============================================================
# 340 is composite | Step 3
# 0.01714920997619629
# ============================================================
# 341 is composite | Step 3
# 0.07685399055480957
# ============================================================
# 342 is composite | Step 3
# 0.0169985294342041
# ============================================================
# 343 is composite | Step 1
# 0.0019791126251220703
# ============================================================
# 344 is composite | Step 3
# 0.01637578010559082
# ============================================================
# 345 is composite | Step 3
# 0.08858752250671387
# ============================================================
# 346 is composite | Step 3
# 0.07983946800231934
# ============================================================
# 347 is prime | Step 3
# 0.7878296375274658
# ============================================================
# 348 is composite | Step 3
# 0.02608489990234375
# ============================================================
# 349 is prime | Step 3
# 0.6937847137451172
# ============================================================
# 350 is composite | Step 3
# 0.07811498641967773
# ============================================================
# 351 is composite | Step 3
# 0.027388811111450195
# ============================================================
# 352 is composite | Step 3
# 0.07754302024841309
# ============================================================
# 353 is prime | Step 3
# 0.8089871406555176
# ============================================================
# 354 is composite | Step 3
# 0.02877211570739746
# ============================================================
# 355 is composite | Step 3
# 0.08222007751464844
# ============================================================
# 356 is composite | Step 3
# 0.07777285575866699
# ============================================================
# 357 is composite | Step 3
# 0.031120777130126953
# ============================================================
# 358 is composite | Step 3
# 0.08381271362304688
# ============================================================
# 359 is prime | Step 3
# 0.7439961433410645
# ============================================================
# 360 is composite | Step 3
# 0.07428383827209473
# ============================================================
# 361 is composite | Step 1
# 6.67572021484375e-05
# ============================================================
# 362 is composite | Step 3
# 0.062254905700683594
# ============================================================
# 363 is composite | Step 3
# 0.036858558654785156
# ============================================================
# 364 is composite | Step 3
# 0.07385730743408203
# ============================================================
# 365 is composite | Step 3
# 0.09229660034179688
# ============================================================
# 366 is composite | Step 3
# 0.02663445472717285
# ============================================================
# 367 is prime | Step 3
# 0.6901857852935791
# ============================================================
# 368 is composite | Step 3
# 0.03460502624511719
# ============================================================
# 369 is composite | Step 3
# 0.05765032768249512
# ============================================================
# 370 is composite | Step 3
# 0.023873090744018555
# ============================================================
# 371 is composite | Step 3
# 0.0736837387084961
# ============================================================
# 372 is composite | Step 3
# 0.09121084213256836
# ============================================================
# 373 is prime | Step 3
# 0.5146040916442871
# ============================================================
# 374 is composite | Step 3
# 0.021797895431518555
# ============================================================
# 375 is composite | Step 3
# 0.07848763465881348
# ============================================================
# 376 is composite | Step 3
# 0.023749113082885742
# ============================================================
# 377 is composite | Step 3
# 0.08205986022949219
# ============================================================
# 378 is composite | Step 3
# 0.02050328254699707
# ============================================================
# 379 is prime | Step 3
# 0.5689969062805176
# ============================================================
# 380 is composite | Step 3
# 0.018486499786376953
# ============================================================
# 381 is composite | Step 3
# 0.01782059669494629
# ============================================================
# 382 is composite | Step 3
# 0.0714879035949707
# ============================================================
# 383 is prime | Step 3
# 0.5144219398498535
# ============================================================
# 384 is composite | Step 3
# 0.07022786140441895
# ============================================================
# 385 is composite | Step 3
# 0.01938176155090332
# ============================================================
# 386 is composite | Step 3
# 0.018555402755737305
# ============================================================
# 387 is composite | Step 3
# 0.07010102272033691
# ============================================================
# 388 is composite | Step 3
# 0.025475740432739258
# ============================================================
# 389 is prime | Step 3
# 1.0072617530822754
# ============================================================
# 390 is composite | Step 3
# 0.07908034324645996
# ============================================================
# 391 is composite | Step 3
# 0.021871328353881836
# ============================================================
# 392 is composite | Step 3
# 0.07251811027526855
# ============================================================
# 393 is composite | Step 3
# 0.02314448356628418
# ============================================================
# 394 is composite | Step 3
# 0.15622973442077637
# ============================================================
# 395 is composite | Step 3
# 0.03154134750366211
# ============================================================
# 396 is composite | Step 3
# 0.07297992706298828
# ============================================================
# 397 is prime | Step 3
# 0.7953481674194336
# ============================================================
# 398 is composite | Step 3
# 0.024054765701293945
# ============================================================
# 399 is composite | Step 3
# 0.08243536949157715
# ============================================================
# 400 is composite | Step 1
# 6.937980651855469e-05
# ============================================================
# 401 is prime | Step 3
# 0.880784273147583
# ============================================================
# 402 is composite | Step 3
# 0.03016209602355957
# ============================================================
# 403 is composite | Step 3
# 0.03395700454711914
# ============================================================
# 404 is composite | Step 3
# 0.0781087875366211
# ============================================================
# 405 is composite | Step 3
# 0.08284997940063477
# ============================================================
# 406 is composite | Step 3
# 0.09238743782043457
# ============================================================
# 407 is composite | Step 3
# 0.09305667877197266
# ============================================================
# 408 is composite | Step 3
# 0.03935980796813965
# ============================================================
# 409 is prime | Step 3
# 1.7129669189453125
# ============================================================
# 410 is composite | Step 3
# 0.05932784080505371
# ============================================================
# 411 is composite | Step 3
# 0.030264616012573242
# ============================================================
# 412 is composite | Step 3
# 0.07914257049560547
# ============================================================
# 413 is composite | Step 3
# 0.08922147750854492
# ============================================================
# 414 is composite | Step 3
# 0.09372353553771973
# ============================================================
# 415 is composite | Step 3
# 0.03069019317626953
# ============================================================
# 416 is composite | Step 3
# 0.08096551895141602
# ============================================================
# 417 is composite | Step 3
# 0.09226369857788086
# ============================================================
# 418 is composite | Step 3
# 0.036940813064575195
# ============================================================
# 419 is prime | Step 3
# 0.802166223526001
# ============================================================
# 420 is composite | Step 3
# 0.0749666690826416
# ============================================================
# 421 is prime | Step 3
# 0.7038147449493408
# ============================================================
# 422 is composite | Step 3
# 0.08474135398864746
# ============================================================
# 423 is composite | Step 3
# 0.028133630752563477
# ============================================================
# 424 is composite | Step 3
# 0.0760948657989502
# ============================================================
# 425 is composite | Step 3
# 0.08788299560546875
# ============================================================
# 426 is composite | Step 3
# 0.12700581550598145
# ============================================================
# 427 is composite | Step 3
# 0.037459611892700195
# ============================================================
# 428 is composite | Step 3
# 0.06832361221313477
# ============================================================
# 429 is composite | Step 3
# 0.08735466003417969
# ============================================================
# 430 is composite | Step 3
# 0.0244903564453125
# ============================================================
# 431 is prime | Step 3
# 0.9060282707214355
# ============================================================
# 432 is composite | Step 3
# 0.06911611557006836
# ============================================================
# 433 is prime | Step 3
# 0.7214248180389404
# ============================================================
# 434 is composite | Step 3
# 0.07880830764770508
# ============================================================
# 435 is composite | Step 3
# 0.07750630378723145
# ============================================================
# 436 is composite | Step 3
# 0.030340194702148438
# ============================================================
# 437 is composite | Step 3
# 0.09524846076965332
# ============================================================
# 438 is composite | Step 3
# 0.09891033172607422
# ============================================================
# 439 is prime | Step 3
# 0.78829026222229
# ============================================================
# 440 is composite | Step 3
# 0.03478050231933594
# ============================================================
# 441 is composite | Step 1
# 5.364418029785156e-05
# ============================================================
# 442 is composite | Step 3
# 0.07140946388244629
# ============================================================
# 443 is prime | Step 3
# 1.0917186737060547
# ============================================================
# 444 is composite | Step 3
# 0.02629995346069336
# ============================================================
# 445 is composite | Step 3
# 0.06677103042602539
# ============================================================
# 446 is composite | Step 3
# 0.0421748161315918
# ============================================================
# 447 is composite | Step 3
# 0.06718325614929199
# ============================================================
# 448 is composite | Step 3
# 0.0940866470336914
# ============================================================
# 449 is prime | Step 3
# 0.7200512886047363
# ============================================================
# 450 is composite | Step 3
# 0.07784056663513184
# ============================================================
# 451 is composite | Step 3
# 0.05242109298706055
# ============================================================
# 452 is composite | Step 3
# 0.052303314208984375
# ============================================================
# 453 is composite | Step 3
# 0.10105681419372559
# ============================================================
# ...
# ============================================================
# 16238 is composite | Step 3
# 0.035536766052246094
# ============================================================
# 16239 is composite | Step 3
# 0.03426480293273926
# ============================================================
# 16240 is composite | Step 3
# 0.0969078540802002
# ============================================================
# 16241 is composite | Step 3
# 0.2073206901550293
# ============================================================
# 16242 is composite | Step 3
# 0.09743309020996094
# ============================================================
# 16243 is composite | Step 3
# 0.18271946907043457
# ============================================================
# 16244 is composite | Step 3
# 0.08800196647644043
# ============================================================
# 16245 is composite | Step 3
# 0.03530383110046387
# ============================================================
# 16246 is composite | Step 3
# 0.08833098411560059
# ============================================================
# 16247 is composite | Step 3
# 0.09442496299743652
# ============================================================
# 16248 is composite | Step 3
# 0.0874166488647461
# ============================================================
# 16249 is prime | Step 3
# 7.609057188034058
# ============================================================
# 16250 is composite | Step 3
# 0.1893444061279297
# ============================================================
# 16251 is composite | Step 3
# 0.18973350524902344
# ============================================================
# 16252 is composite | Step 3
# 0.10769104957580566
# ============================================================
# 16253 is prime | Step 3
# 7.424821138381958
# ============================================================
# 16254 is composite | Step 3
# 0.10764336585998535
# ============================================================
# 16255 is composite | Step 3
# 0.08899068832397461
# ============================================================
# 16256 is composite | Step 3
# 0.10264158248901367
# ============================================================
# 16257 is composite | Step 3
# 0.08944582939147949
# ============================================================
# 16258 is composite | Step 3
# 0.10590028762817383
# ============================================================
# 16259 is composite | Step 3
# 0.17695951461791992
# ============================================================
# 16260 is composite | Step 3
# 0.03835439682006836
# ============================================================
# 16261 is composite | Step 3
# 0.08582878112792969
# ============================================================
# 16262 is composite | Step 3
# 0.08498001098632812
# ============================================================
# 16263 is composite | Step 3
# 0.08622503280639648
# ============================================================
# 16264 is composite | Step 3
# 0.033033132553100586
# ============================================================
# 16265 is composite | Step 3
# 0.08483338356018066
# ============================================================
# 16266 is composite | Step 3
# 0.08901095390319824
# ============================================================
# 16267 is prime | Step 3
# 8.49118971824646
# ============================================================
# 16268 is composite | Step 3
# 0.03815126419067383
# ============================================================
# 16269 is composite | Step 3
# 0.09938263893127441
# ============================================================
# 16270 is composite | Step 3
# 0.09383916854858398
# ============================================================
# 16271 is composite | Step 3
# 0.1110529899597168
# ============================================================
# 16272 is composite | Step 3
# 0.09643173217773438
# ============================================================
# 16273 is prime | Step 3
# 7.207672595977783
# ============================================================
# 16274 is composite | Step 3
# 0.08725476264953613
# ============================================================
# 16275 is composite | Step 3
# 0.08672022819519043
# ============================================================
# 16276 is composite | Step 3
# 0.09200692176818848
# ============================================================
# 16277 is composite | Step 3
# 0.09892749786376953
# ============================================================
# 16278 is composite | Step 3
# 0.0338129997253418
# ============================================================
# 16279 is composite | Step 3
# 0.19243645668029785
# ============================================================
# 16280 is composite | Step 3
# 0.10453939437866211
# ============================================================
# 16281 is composite | Step 3
# 0.15941572189331055
# ============================================================
# 16282 is composite | Step 3
# 0.11296272277832031
# ============================================================
# 16283 is composite | Step 3
# 0.1187283992767334
# ============================================================
# 16284 is composite | Step 3
# 0.10910725593566895
# ============================================================
# 16285 is composite | Step 3
# 0.1631772518157959
# ============================================================
# 16286 is composite | Step 3
# 0.033896684646606445
# ============================================================
# 16287 is composite | Step 3
# 0.08565163612365723
# ============================================================
# 16288 is composite | Step 3
# 0.08537817001342773
# ============================================================
# 16289 is composite | Step 3
# 0.08963513374328613
# ============================================================
# 16290 is composite | Step 3
# 0.04618382453918457
# ============================================================
# 16291 is composite | Step 3
# 0.08967018127441406
# ============================================================
# 16292 is composite | Step 3
# 0.08616042137145996
# ============================================================
# 16293 is composite | Step 3
# 0.09510326385498047
# ============================================================
# 16294 is composite | Step 3
# 0.09842133522033691
# ============================================================
# 16295 is composite | Step 3
# 0.09373688697814941
# ============================================================
# 16296 is composite | Step 3
# 0.09199070930480957
# ============================================================
# 16297 is composite | Step 3
# 0.11893606185913086
# ============================================================
# 16298 is composite | Step 3
# 0.11255288124084473
# ============================================================
# 16299 is composite | Step 3
# 0.09641695022583008
# ============================================================
# 16300 is composite | Step 3
# 0.09851646423339844
# ============================================================
# 16301 is prime | Step 3
# 9.379985332489014
# ============================================================
# 16302 is composite | Step 3
# 0.11575484275817871
# ============================================================
# 16303 is composite | Step 3
# 0.13857221603393555
# ============================================================
# 16304 is composite | Step 3
# 0.1346900463104248
# ============================================================
# 16305 is composite | Step 3
# 0.03801774978637695
# ============================================================
# 16306 is composite | Step 3
# 0.09100461006164551
# ============================================================
# 16307 is composite | Step 3
# 0.09910964965820312
# ============================================================
# 16308 is composite | Step 3
# 0.09747481346130371
# ============================================================
# 16309 is composite | Step 3
# 0.17630624771118164
# ============================================================
# 16310 is composite | Step 3
# 0.10816144943237305
# ============================================================
# 16311 is composite | Step 3
# 0.1146085262298584
# ============================================================
# 16312 is composite | Step 3
# 0.12749648094177246
# ============================================================
# 16313 is composite | Step 3
# 0.1297140121459961
# ============================================================
# 16314 is composite | Step 3
# 0.09430742263793945
# ============================================================
# 16315 is composite | Step 3
# 0.18782281875610352
# ============================================================
# 16316 is composite | Step 3
# 0.09390377998352051
# ============================================================
# 16317 is composite | Step 3
# 0.08283305168151855
# ============================================================
# 16318 is composite | Step 3
# 0.10584354400634766
# ============================================================
# 16319 is prime | Step 3
# 11.400633096694946
# ============================================================
# 16320 is composite | Step 3
# 0.1530764102935791
# ============================================================
# 16321 is composite | Step 3
# 0.12137532234191895
# ============================================================
# 16322 is composite | Step 3
# 0.09413647651672363
# ============================================================
# 16323 is composite | Step 3
# 0.11118698120117188
# ============================================================
# 16324 is composite | Step 3
# 0.12109112739562988
# ============================================================
# 16325 is composite | Step 3
# 0.15421128273010254
# ============================================================
# 16326 is composite | Step 3
# 0.09876608848571777
# ============================================================
# 16327 is composite | Step 3
# 0.11779928207397461
# ============================================================
# 16328 is composite | Step 3
# 0.10674619674682617
# ============================================================
# 16329 is composite | Step 3
# 0.10910439491271973
# ============================================================
# 16330 is composite | Step 3
# 0.1138608455657959
# ============================================================
# 16331 is composite | Step 3
# 0.10149025917053223
# ============================================================
# 16332 is composite | Step 3
# 0.09169483184814453
# ============================================================
# 16333 is prime | Step 3
# 9.594958782196045
# ============================================================
# 16334 is composite | Step 3
# 0.09362554550170898
# ============================================================
# 16335 is composite | Step 3
# 0.09151577949523926
# ============================================================
# 16336 is composite | Step 3
# 0.09264802932739258
# ============================================================
# 16337 is composite | Step 3
# 0.11700153350830078
# ============================================================
# 16338 is composite | Step 3
# 0.10930538177490234
# ============================================================
# 16339 is prime | Step 3
# 10.06331467628479
# ============================================================
# 16340 is composite | Step 3
# 0.11109805107116699
# ============================================================
# 16341 is composite | Step 3
# 0.10001373291015625
# ============================================================
# 16342 is composite | Step 3
# 0.1175541877746582
# ============================================================
# 16343 is composite | Step 3
# 0.18274950981140137
# ============================================================
# 16344 is composite | Step 3
# 0.10103678703308105
# ============================================================
# 16345 is composite | Step 3
# 0.1093146800994873
# ============================================================
# 16346 is composite | Step 3
# 0.10452771186828613
# ============================================================
# 16347 is composite | Step 3
# 0.11213040351867676
# ============================================================
# 16348 is composite | Step 3
# 0.1542048454284668
# ============================================================
# 16349 is prime | Step 3
# 10.523618698120117
# ============================================================
# 16350 is composite | Step 3
# 0.1085205078125
# ============================================================
# 16351 is composite | Step 3
# 0.2131493091583252
# ============================================================
# 16352 is composite | Step 3
# 0.15382671356201172
# ============================================================
# 16353 is composite | Step 3
# 0.10933709144592285
# ============================================================
# 16354 is composite | Step 3
# 0.11229157447814941
# ============================================================
# 16355 is composite | Step 3
# 0.09317684173583984
# ============================================================
# 16356 is composite | Step 3
# 0.11659836769104004
# ============================================================
# 16357 is composite | Step 3
# 0.11173415184020996
# ============================================================
# 16358 is composite | Step 3
# 0.09943032264709473
# ============================================================
# 16359 is composite | Step 3
# 0.10157370567321777
# ============================================================
# 16360 is composite | Step 3
# 0.15804100036621094
# ============================================================
# 16361 is prime | Step 3
# 10.221652269363403
# ============================================================
# 16362 is composite | Step 3
# 0.10719466209411621
# ============================================================
# 16363 is prime | Step 3
# 9.775561571121216
# ============================================================
# 16364 is composite | Step 3
# 0.11449122428894043
# ============================================================
# 16365 is composite | Step 3
# 0.10069894790649414
# ============================================================
# 16366 is composite | Step 3
# 0.10448932647705078
# ============================================================
# 16367 is composite | Step 3
# 0.17305612564086914
# ============================================================
# 16368 is composite | Step 3
# 0.10816454887390137
# ============================================================
# 16369 is prime | Step 3
# 9.202113389968872
# ============================================================
# 16370 is composite | Step 3
# 0.1218099594116211
# ============================================================
# 16371 is composite | Step 3
# 0.10978841781616211
# ============================================================
# 16372 is composite | Step 3
# 0.16147351264953613
# ============================================================
# 16373 is composite | Step 3
# 0.10772085189819336
# ============================================================
# 16374 is composite | Step 3
# 0.03509807586669922
# ============================================================
# 16375 is composite | Step 3
# 0.11561727523803711
# ============================================================
# 16376 is composite | Step 3
# 0.09498262405395508
# ============================================================
# 16377 is composite | Step 3
# 0.03562283515930176
# ============================================================
# 16378 is composite | Step 3
# 0.09005522727966309
# ============================================================
# 16379 is composite | Step 3
# 0.09735512733459473
# ============================================================
# 16380 is composite | Step 3
# 0.1002805233001709
# ============================================================
# 16381 is prime | Step 3
# 8.590442657470703
# ============================================================
# 16382 is composite | Step 3
# 0.08733654022216797
# ============================================================
# 16383 is composite | Step 3
# 0.09951615333557129
# ============================================================
# WARNING: 2299 intermediate output messages were discarded.
# WARNING: some intermediate output was truncated.

# %%
plt.figure(figsize=(16,8))
plt.plot(numbers, times)
plt.title('Number/time')
plt.xlabel('Number')
plt.ylabel('Time')
# Out:
# Text(0, 0.5, 'Time')
